# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/linkedin-reviews.csv")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702 entries, 0 to 701
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  702 non-null    object
#  1   Rating  702 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 11.1+ KB

# %% [markdown]
# # **Plotting the Distribution of Ratings**

# %%
sns.set(style = 'whitegrid')
plt.figure(figsize = (9,5))
sns.countplot(data = df, x = 'Rating')
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# %%
# !pip install textblob

# %%
from textblob import TextBlob

# %%
def textblob_sentiment_analysis(review):
    sentiment = TextBlob(review).sentiment
    if sentiment.polarity > 0.1 :
        return 'Positive'
    elif sentiment.polarity < -0.1 :
        return 'Negative'
    else :
        return 'Neutral'

# %%
df['Sentiment'] = df['Review']. apply(textblob_sentiment_analysis)

# %%
df.sample(5)
# Out:
#                                                 Review  Rating Sentiment
# 608  Good program rewrite is excellent. works great...       4  Positive
# 313                  It just logs in and does nothing!       1   Neutral
# 412  The application does not work with this latest...       1  Positive
# 363  Was half decent, but can't even open app since...       1   Neutral
# 697  Can't trust, Going to uninstall just for that ...       1   Neutral

# %% [markdown]
# # **Analyzing App Reviews Sentiments**

# %%
sentiment_distribution = df['Sentiment']. value_counts ()
sentiment_distribution
# Out:
# Sentiment
# Neutral     300
# Positive    295
# Negative    107
# Name: count, dtype: int64

# %%
plt.figure(figsize = (9,5))
sns.barplot(x= sentiment_distribution.index,
y = sentiment_distribution.values)
plt.title('Distribution of Sentiments')
plt.xlabel('Sentiment')
plt.ylabel(' Count')
plt.show()

# %% [markdown]
# # ***so, we can see althrough the app has low ratings, still the reviewers don't use many negative words in the reviews for the app.***
# Next, we'll explore the relationship between the sentiments and the ratings. This analysis can help us understand whether there is a correlation between the sentiment of the text and numerical ratinas.

# %%
plt.figure(figsize = (10,5))
sns.countplot(data = df,
        x = 'Rating',
        hue = 'Sentiment')
plt.xlabel('Rating')
plt.ylabel(' Count')
plt.legend(title='Sentiment')
plt.show()
